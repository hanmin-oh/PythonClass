# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Computer.use_jedi = False
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns # matplotlib을 확장한 시각화 라이브러리

# %%
# load_dataset() 메소드를 사용해서 seaborn이 제공하는 데이터셋을 읽어 데이터프레임으로 얻어올 수 있다. 
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# 자료형 변환하기

# %%
# pandas의 category는 R의 factor와 같은 범주형 데이터를 의미한다. => 연산을 위한 데이터가 아니고 분류를 위한 데이터이다.
# pandas의 object는 문자형 데이터를 의미한다. 
print(tips.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# astype() 메소드를 사용해서 자료형을 변경할 수 있다. 
# tims열의 데이터를 category 타입에서 object 타입으로 변환해서 tips_str 이라는 새로운 열에 저장한다. 
tips['time_str'] = tips['time'].astype(str)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size time_str
# 0         16.99  1.01  Female     No   Sun  Dinner     2   Dinner
# 1         10.34  1.66    Male     No   Sun  Dinner     3   Dinner
# 2         21.01  3.50    Male     No   Sun  Dinner     3   Dinner
# 3         23.68  3.31    Male     No   Sun  Dinner     2   Dinner
# 4         24.59  3.61  Female     No   Sun  Dinner     4   Dinner
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   Dinner
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   Dinner
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   Dinner
# 242       17.82  1.75    Male     No   Sat  Dinner     2   Dinner
# 243       18.78  3.00  Female     No  Thur  Dinner     2   Dinner
#
# [244 rows x 8 columns]

# %%
print(tips.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# time_str        object
# dtype: object

# %%
tips_sub_miss = tips.head(10)
tips_sub_miss
# Out:
#    total_bill   tip     sex smoker  day    time  size time_str
# 0       16.99  1.01  Female     No  Sun  Dinner     2   Dinner
# 1       10.34  1.66    Male     No  Sun  Dinner     3   Dinner
# 2       21.01  3.50    Male     No  Sun  Dinner     3   Dinner
# 3       23.68  3.31    Male     No  Sun  Dinner     2   Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner     4   Dinner
# 5       25.29  4.71    Male     No  Sun  Dinner     4   Dinner
# 6        8.77  2.00    Male     No  Sun  Dinner     2   Dinner
# 7       26.88  3.12    Male     No  Sun  Dinner     4   Dinner
# 8       15.04  1.96    Male     No  Sun  Dinner     2   Dinner
# 9       14.78  3.23    Male     No  Sun  Dinner     2   Dinner

# %%
# tips_sub_miss.loc[[1,3,5,7,], 'total_bill'] = 'missing'
tips_sub_miss.loc[[1,3,5,7,], 0] = 'missing' #위의 코드와 동일
tips_sub_miss
# Out:
#   total_bill   tip     sex smoker  day    time  size time_str        0
# 0      16.99  1.01  Female     No  Sun  Dinner     2   Dinner      NaN
# 1    missing  1.66    Male     No  Sun  Dinner     3   Dinner  missing
# 2      21.01  3.50    Male     No  Sun  Dinner     3   Dinner      NaN
# 3    missing  3.31    Male     No  Sun  Dinner     2   Dinner  missing
# 4      24.59  3.61  Female     No  Sun  Dinner     4   Dinner      NaN
# 5    missing  4.71    Male     No  Sun  Dinner     4   Dinner  missing
# 6       8.77  2.00    Male     No  Sun  Dinner     2   Dinner      NaN
# 7    missing  3.12    Male     No  Sun  Dinner     4   Dinner  missing
# 8      15.04  1.96    Male     No  Sun  Dinner     2   Dinner      NaN
# 9      14.78  3.23    Male     No  Sun  Dinner     2   Dinner      NaN

# %%
print(tips_sub_miss.dtypes)
# Out:
# total_bill      object
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# time_str        object
# 0               object
# dtype: object

# %%
# 문자열 때문에 에러가 발생한다. 
# tips_sub_miss['total_bill'] = tips_sub_miss['total_bill'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # 문자열 때문에 에러가 발생한다.
# ----> 2 tips_sub_miss['total_bill'] = tips_sub_miss['total_bill'].astype(float)
#
# File c:\python\lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File c:\python\lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# to_numeric() 메소드를 사용해도 어느정도 오류 제어를 할 수 있다.
# errors속성을 지정하지 않으면 'raise'가 기본 속성이고 ignore로 지정하면 to_numeric의 메소드를 실행하지 않는다.
# tips_sub_miss['total_bill'] = pd.to_numeric(tips_sub_miss['total_Bill'], errors='raise') #에러
tips_sub_miss['total_bill'] = pd.to_numeric(tips_sub_miss['total_bill'], errors='ignore')
tips_sub_miss
# Out:
#   total_bill   tip     sex smoker  day    time  size time_str        0
# 0      16.99  1.01  Female     No  Sun  Dinner     2   Dinner      NaN
# 1    missing  1.66    Male     No  Sun  Dinner     3   Dinner  missing
# 2      21.01  3.50    Male     No  Sun  Dinner     3   Dinner      NaN
# 3    missing  3.31    Male     No  Sun  Dinner     2   Dinner  missing
# 4      24.59  3.61  Female     No  Sun  Dinner     4   Dinner      NaN
# 5    missing  4.71    Male     No  Sun  Dinner     4   Dinner  missing
# 6       8.77  2.00    Male     No  Sun  Dinner     2   Dinner      NaN
# 7    missing  3.12    Male     No  Sun  Dinner     4   Dinner  missing
# 8      15.04  1.96    Male     No  Sun  Dinner     2   Dinner      NaN
# 9      14.78  3.23    Male     No  Sun  Dinner     2   Dinner      NaN

# %%
# errors속성을 'coerce'로 지정하면 오류가 발생되는 데이터를 누락값으로 변경한다. 
tips_sub_miss['total_bill'] = pd.to_numeric(tips_sub_miss['total_bill'], errors='coerce')
tips_sub_miss
# Out:
#    total_bill   tip     sex smoker  day    time  size time_str        0
# 0       16.99  1.01  Female     No  Sun  Dinner     2   Dinner      NaN
# 1         NaN  1.66    Male     No  Sun  Dinner     3   Dinner  missing
# 2       21.01  3.50    Male     No  Sun  Dinner     3   Dinner      NaN
# 3         NaN  3.31    Male     No  Sun  Dinner     2   Dinner  missing
# 4       24.59  3.61  Female     No  Sun  Dinner     4   Dinner      NaN
# 5         NaN  4.71    Male     No  Sun  Dinner     4   Dinner  missing
# 6        8.77  2.00    Male     No  Sun  Dinner     2   Dinner      NaN
# 7         NaN  3.12    Male     No  Sun  Dinner     4   Dinner  missing
# 8       15.04  1.96    Male     No  Sun  Dinner     2   Dinner      NaN
# 9       14.78  3.23    Male     No  Sun  Dinner     2   Dinner      NaN
