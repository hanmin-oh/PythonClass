# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Computer.use_jedi = False
import requests
import folium
# !pip install pandas # 파이썬 데이터 처리
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='D2Coding')

# %%
import requests

targetSite = 'https://eggdrop.co.kr/api/store.php'
params = {
    'sido': '',  # 시도명
    'gugun': '',  # 구군명
    'storename': '',  # 매장명 (필터링을 위한 검색어)
    'filter1': '',    # 필터 1
    'filter2': '',    # 필터 2
    'filter3': '',    # 필터 3
    'filter4': '',    # 필터 4
    'filter5': ''     # 필터 5
}

response = requests.get(targetSite, params=params)
eggdrop = response.json()

# print(eggdrop)
print(type(eggdrop))
# Out:
# <class 'dict'>

# %%
eggdrop_df = pd.json_normalize(eggdrop, 'data')
print(type(eggdrop_df)) # <class 'pandas.core.frame.DataFrame'>
print(len(eggdrop_df))
print(eggdrop_df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 188
# Index(['seq', 'storecode', 'title_kr', 'title_en', 'phone', 'operatingtime',
#        'sido', 'gugun', 'zipcode', 'addr1', 'smartstore', 'latitude',
#        'longitude', 'option1', 'option2', 'option3', 'option4', 'option5',
#        'image_web', 'image_mobile'],
#       dtype='object')

# %%
eggdrop_df
# Out:
#      seq storecode         title_kr title_en          phone operatingtime  \
# 0    103                   <폐점>수원역점            031-253-0582   10:00-22:00
# 1    179                  <폐점>양주옥정점            031-861-6051   09:30-21:00
# 2    136            <폐점230219>수원망포점            031-206-4755   08:00-20:30
# 3    302                      AK금정점                      미정   10:30~21:00
# 4    170                      NC구로점            02-6923-2107   10:30-22:00
# ..   ...       ...              ...      ...            ...           ...
# 183    8                    홈플러스목동점            02-2652-1222   10:00-21:30
# 184   72                      홍대입구점            02-6085-4371   08:00-22:00
# 185  221                      화성병점점           070-4115-8464   08:30-20:30
# 186  214                      화성봉담점           031-5183-3835   10:00-21:00
# 187  127                      화성향남점           031-8043-5999   10:00-20:00
#
#       sido gugun zipcode                               addr1  \
# 0      경기도   수원시   16455                   경기 수원시 팔달구 향교로 23
# 1      경기도   양주시                  경기 양주시 옥정동로7다길 12-13, 119호
# 2      경기도         16687                   경기 수원시 영통구 태장로 84
# 3      경기도   군포시    None  경기 군포시 금정동 689 AK플라자 금정점 1층 푸드코트 내
# 4    서울특별시   구로구   08292                    서울 구로구 구로중앙로 152
# ..     ...   ...     ...                                 ...
# 183  서울특별시   양천구   07992               서울 양천구 목동서로 170 지상 1층
# 184  서울특별시   마포구   04040                        서울 마포구 홍익로15
# 185    경기도   화성시   18405                     경기 화성시 효행로 1062
# 186    경기도   화성시   18303                   경기 화성시 봉담읍 동화길 51
# 187    경기도   화성시   18591                  경기 화성시 향남읍 발안로 107
#
#                                             smartstore   latitude   longitude  \
# 0                             http://naver.me/F5b8vNfU  37.268479  127.003557
# 1                             http://naver.me/F8KlLaZk  37.819274  127.093461
# 2                             http://naver.me/xTeMTouJ  37.238992  127.055600
# 3    https://map.naver.com/v5/entry/place/140108212...  37.372859  126.943916
# 4                             http://naver.me/F5bOLldY  37.501161  126.882594
# ..                                                 ...        ...         ...
# 183                           http://naver.me/5MU1hLSC  37.530141  126.873108
# 184                           http://naver.me/GnGCgHkS  37.553716  126.923007
# 185                           http://naver.me/5U1GZZYd  37.214487  127.043459
# 186                           http://naver.me/GHEKXlEw  37.219019  126.955378
# 187                           http://naver.me/GIqM1rwQ  37.131676  126.922441
#
#      option1  option2  option3  option4  option5 image_web image_mobile
# 0      False    False    False    False    False
# 1      False    False    False    False    False
# 2      False    False    False    False    False
# 3      False    False    False    False    False
# 4      False    False    False    False    False
# ..       ...      ...      ...      ...      ...       ...          ...
# 183    False    False    False    False    False
# 184    False    False    False    False    False
# 185    False    False    False    False    False
# 186    False    False    False    False    False
# 187    False    False    False    False    False
#
# [188 rows x 20 columns]

# %%
eggdrop_df_map = eggdrop_df[
    [
   'seq', 'storecode', 'title_kr', 'phone', 'operatingtime',
       'sido', 'gugun', 'addr1','latitude',
       'longitude'
    ]
]
eggdrop_df_map
# Out:
#      seq storecode         title_kr          phone operatingtime   sido gugun  \
# 0    103                   <폐점>수원역점   031-253-0582   10:00-22:00    경기도   수원시
# 1    179                  <폐점>양주옥정점   031-861-6051   09:30-21:00    경기도   양주시
# 2    136            <폐점230219>수원망포점   031-206-4755   08:00-20:30    경기도
# 3    302                      AK금정점             미정   10:30~21:00    경기도   군포시
# 4    170                      NC구로점   02-6923-2107   10:30-22:00  서울특별시   구로구
# ..   ...       ...              ...            ...           ...    ...   ...
# 183    8                    홈플러스목동점   02-2652-1222   10:00-21:30  서울특별시   양천구
# 184   72                      홍대입구점   02-6085-4371   08:00-22:00  서울특별시   마포구
# 185  221                      화성병점점  070-4115-8464   08:30-20:30    경기도   화성시
# 186  214                      화성봉담점  031-5183-3835   10:00-21:00    경기도   화성시
# 187  127                      화성향남점  031-8043-5999   10:00-20:00    경기도   화성시
#
#                                   addr1   latitude   longitude
# 0                     경기 수원시 팔달구 향교로 23  37.268479  127.003557
# 1            경기 양주시 옥정동로7다길 12-13, 119호  37.819274  127.093461
# 2                     경기 수원시 영통구 태장로 84  37.238992  127.055600
# 3    경기 군포시 금정동 689 AK플라자 금정점 1층 푸드코트 내  37.372859  126.943916
# 4                      서울 구로구 구로중앙로 152  37.501161  126.882594
# ..                                  ...        ...         ...
# 183               서울 양천구 목동서로 170 지상 1층  37.530141  126.873108
# 184                        서울 마포구 홍익로15  37.553716  126.923007
# 185                     경기 화성시 효행로 1062  37.214487  127.043459
# 186                   경기 화성시 봉담읍 동화길 51  37.219019  126.955378
# 187                  경기 화성시 향남읍 발안로 107  37.131676  126.922441
#
# [188 rows x 10 columns]

# %%
# dtype 속성으로 데이터 프레임을 구성하는 컬럼들의 자료형을 확인할 수 있다.
eggdrop_df_map.dtypes
# Out:
# seq                int64
# storecode         object
# title_kr          object
# title_en          object
# phone             object
# operatingtime     object
# sido              object
# gugun             object
# zipcode           object
# addr1             object
# smartstore        object
# latitude         float64
# longitude        float64
# image_web         object
# image_mobile      object
# dtype: object

# %%
# info() 메소드를 사용해도 데이터프레임을 구성하는 컬럼들의 자료형을 확인할 수 있다.
eggdrop_df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   seq            2 non-null      int64
#  1   storecode      2 non-null      object
#  2   title_kr       2 non-null      object
#  3   title_en       2 non-null      object
#  4   phone          2 non-null      object
#  5   operatingtime  2 non-null      object
#  6   sido           2 non-null      object
#  7   gugun          2 non-null      object
#  8   zipcode        1 non-null      object
#  9   addr1          2 non-null      object
#  10  smartstore     2 non-null      object
#  11  latitude       2 non-null      float64
#  12  longitude      2 non-null      float64
#  13  image_web      2 non-null      object
#  14  image_mobile   2 non-null      object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 368.0+ bytes

# %%
eggdrop_df_map[eggdrop_df_map['title_kr'] == '세종아름점']
# Out:
#    seq storecode title_kr title_en         phone operatingtime sido gugun  \
# 1  286              세종아름점           044-905-0102   09:00~21:00  세종시   세종시
#
#   zipcode            addr1                                       smartstore  \
# 1    None  세종특별자치시 보듬3로 91  https://map.naver.com/v5/entry/place/1800253400
#
#    latitude   longitude image_web image_mobile
# 1  36.51156  127.249449

# %%
eggdropMap = folium.Map(location=[36.51156 , 127.249449], zoom_start=17)
popup = folium.Popup('세종아름점',max_width=300)
folium.Marker(location=[36.51156 , 127.249449] , popup=popup).add_to(eggdropMap)
popup = folium.Popup('세종새롬점',max_width=300)
folium.Marker(location=[36.484948 , 127.250905] , popup=popup).add_to(eggdropMap)
eggdropMap.save('./eggdrop.html')
eggdropMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5aabb453fe2785f92c205ae33177ec21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5aabb453fe2785f92c205ae33177ec21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5aabb453fe2785f92c205ae33177ec21 = L.map(
#                 &quot;map_5aabb453fe2785f92c205ae33177ec21&quot;,
#                 {
#                     center: [36.51156, 127.249449],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_132a1f8140dc22ad00b557d98523b9e0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5aabb453fe2785f92c205ae33177ec21);
#
#
#             var marker_52163709918e82afeb5225adf15f988d = L.marker(
#                 [36.51156, 127.249449],
#                 {}
#             ).addTo(map_5aabb453fe2785f92c205ae33177ec21);
#
#
#         var popup_758cd0406a4eee7750e8b83a82797e1a = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_377e65dd42420d10f1db8be19ae13532 = $(`&lt;div id=&quot;html_377e65dd42420d10f1db8be19ae13532&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;세종아름점&lt;/div&gt;`)[0];
#                 popup_758cd0406a4eee7750e8b83a82797e1a.setContent(html_377e65dd42420d10f1db8be19ae13532);
#
#
#
#         marker_52163709918e82afeb5225adf15f988d.bindPopup(popup_758cd0406a4eee7750e8b83a82797e1a)
#         ;
#
#
#
#
#             var marker_c457f8e346132ed54779aeada65b13d8 = L.marker(
#                 [36.484948, 127.250905],
#                 {}
#             ).addTo(map_5aabb453fe2785f92c205ae33177ec21);
#
#
#         var popup_48bb8130c53360fc9bdb4a7a4785abba = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_c8d6a4a0f4ae71d5819a4bc5bb89f87c = $(`&lt;div id=&quot;html_c8d6a4a0f4ae71d5819a4bc5bb89f87c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;세종새롬점&lt;/div&gt;`)[0];
#                 popup_48bb8130c53360fc9bdb4a7a4785abba.setContent(html_c8d6a4a0f4ae71d5819a4bc5bb89f87c);
#
#
#
#         marker_c457f8e346132ed54779aeada65b13d8.bindPopup(popup_48bb8130c53360fc9bdb4a7a4785abba)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests

targetSite = 'https://eggdrop.co.kr/api/store.php'
params = {
    'sido': '',  # 시도명
    'gugun': '',  # 구군명
    'storename': '',  # 매장명 (필터링을 위한 검색어)
    'filter1': '',    # 필터 1
    'filter2': '',    # 필터 2
    'filter3': '',    # 필터 3
    'filter4': '',    # 필터 4
    'filter5': ''     # 필터 5
}

response = requests.get(targetSite, params=params)
eggdrop = response.json()
eggdrop_df = pd.json_normalize(eggdrop, 'data')
print(type(eggdrop_df)) # <class 'pandas.core.frame.DataFrame'>
print(len(eggdrop_df))
print(eggdrop_df.columns)
# print(eggdrop)
# print(type(eggdrop))
eggdrop_df_map = eggdrop_df[
    [
   'seq', 'storecode', 'title_kr', 'phone', 'operatingtime',
       'sido', 'gugun', 'addr1','latitude',
       'longitude'
    ]
]
eggdrop_df_map
eggdropMap = folium.Map(location=[36.51156 , 127.249449], zoom_start=17)
for index, data in eggdrop_df_map.iterrows():
    popup = folium.Popup('{}. {} -{}'.format(index+1 , data['title_kr'], data['addr1']) , max_width=300)
    folium.Marker(location=[data['latitude'],data['longitude']] , popup=popup).add_to(eggdropMap)
eggdropMap.save('./eggdrop전국.html')
eggdropMap
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 188
# Index(['seq', 'storecode', 'title_kr', 'title_en', 'phone', 'operatingtime',
#        'sido', 'gugun', 'zipcode', 'addr1', 'smartstore', 'latitude',
#        'longitude', 'option1', 'option2', 'option3', 'option4', 'option5',
#        'image_web', 'image_mobile'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2705d662153e63dc55e0226f7b79280a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2705d662153e63dc55e0226f7b79280a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2705d662153e63dc55e0226f7b79280a = L.map(
#                 &quot;map_2705d662153e63dc55e0226f7b79280a&quot;,
#                 {
#                     center: [36.51156, 127.249449],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19d17f05b811603e29442549f942ec9b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2705d662153e63dc55e0226f7b79280a);
#
#
#             var marker_240b38dbf025f7af5016e419d657509d = L.marker(
#                 [37.268478512463346, 127.00355702430664],
#                 {}
#             ).addTo(map_2705d662153e63dc55e0226f7b79280a);
#
#
#         var popup_11a724abcd06107a2c318f2a95443c50 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_2e8aea9e4d560a8b3ebea129c359d8f4 = $(`&lt;div id=&quot;html_2e8aea9e4d560a8b3ebea129c359d8f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1. &lt;폐점&gt;수원역점 -경기 수원시 팔달구 향교로 23&lt;/div&gt;`)[0];
#                 popup_11a724abcd06107a2c318f2a95443c50.setContent(html_2e8aea9e4d560a8b3ebea129c359d8f4);
#
#
#
#         marker_240b38dbf025f7af5016e419d657509d.bindPopup(popup_11a724abcd06107a2c318f2a95443c50)
#         ;
#
#
#
#
#             var marker_b887de9218bb536951410859e4007763 = L.marker(
#                 [37.81927422539004, 127.09346082858133],
#                 {}
#             ).addTo(map_2705d662153e63dc55e0226f7b79280a);
#
#
#         var popup_122aaf711320af3cfeb43751944c6c7f = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_fc50a295d35d601036fe10cde6ab7593 = $(`&lt;div id=&quot;html_fc50a295d35d601036fe10cde6ab7593&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2. &lt;폐점&gt;양주옥정점 -경기 양주시 옥정동로7다길 12-13, 119호&lt;/div&gt;`)[0];
#                 popup_122aaf711320af3cfeb43751944c6c7f.setContent(html_fc50a295d35d601036fe10cde6ab7593);
#
#
#
#         marker_b887de9218bb536951410859e4007763.bindPopup(popup_122aaf711320af3cfeb43751944c6c7f)
#         ;
#
#
#
#
#             var marker_9b18410c6e4571cf010e9e724c21e1fa = L.marker(
#                 [37.23899237318997, 127.05559981276167],
#                 {}
#             ).addTo(map_2705d662153e63dc55e0226f7b79280a);
#
#
#         var popup_e564f323ea38dd680fd3edbdde620749 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_c801cbebb143437a40e71f07173c781d = $(`&lt;div id=&quot;html_c801cbebb143437a40e71f07173c781d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3. &lt;폐점230219&gt;수원망포점 -경기 수원시 영통구 태장로 84&lt;/div&gt;`)[0];
#                 popup_e564f323ea38dd680fd3edbdde620749.setContent(html_c801cbebb143437a40e71f07173c781d);
#
#
#
#         marker_9b18410c6e4571cf010e9e724c21e1fa.bindPopup(popup_e564f323ea38dd680fd3edbdde620749)
#         ;
#
#
#
#
#             var marker_233e81701d001e13cb6d5d28d32db3e8 = L.marker(
#                 [37.372859, 126.943916],
#                 {}
#             ).addTo(map_2705d662153e63dc55e0226f7b79280a);
#
#
#         var popup_74608fc20ecce06723e7a60074429c4a = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_3fb23d0e54b703d1aa9b9b1f83a34cc8 = $(`&lt;div id=&quot;html_3fb23d0e54b703d1aa9b9b1f83a34cc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4. AK금정점 -경기 군포시 금정동 689 AK플라자 금정점 1층 푸드코트 내&lt;/div&gt;`)[0];
#                 popup_74608fc20ecce06723e7a60074429c4a.setContent(html_3fb23d0e54b703d1aa9b9b1f83a34cc8);
#
#
#
#         marker_233e81701d001e13cb6d5d28d32db3e8.bindPopup(popup_74608fc20ecce06723e7a60074429c4a)
#         ;
#
#
#
#
#             var marker_89053ce12fecec74e3e2adc8f6286623 = L.marker(
#                 [37.501161408263144, 126.88259421258554],
#                 {}
#             ).addTo(map_2705d662153e63dc55e0226f7b79280a);
#
#
#         var popup_101f5f1fa975e2a96909fbef63afc833 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_b5a96e05bb828722092d5acf0ebd4407 = $(`&lt;div id=&quot;html_b5a96e05bb828722092d5acf0ebd4407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5. NC구로점 -서울 구로구 구로중앙로 152&lt;/div&gt;`)[0];
#                 popup_101f5f1fa975e2a96909fbef63afc833.setContent(html_b5a96e05bb828722092d5acf0ebd4407);
#
#
#
#         marker_89053ce12fecec74e3e2adc8f6286623.bindPopup(popup_101f5f1fa975e2a96909fbef63afc833)
#         ;
