# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Computer.use_jedi = False
import requests
import folium
# !pip install pandas # 파이썬 데이터 처리
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='D2Coding')

# %%
import requests

targetSite = 'https://www.bikeseoul.com/app/station/getStationRealtimeStatus.do'
# request = requests.post(targetSite, data={
#             'mode':'',
#             'parkingBikeTotCnt': '',
#             'parkingELECBikeCnt': '',
#             'parkingQRBikeCnt': '',
#             'rackTotCnt': '',
#             'stationId': '',
#             'stationImgFileName': '',
#             'stationLatitude': '',
#             'stationLongitude': '',
#             'stationName': '',
#             'stationSeCd': ''
# })
request = requests.post(targetSite, data={
           'stationGrpSeq': 'ALL',
            'tabId': 'undefined'
})
bike = request.json()
print(type(bike))
print(len(bike))
print(bike)
# Out:
# <class 'dict'>
# 7
# {'stationImgPath': '/nas_link/spb/attachFiles/file_admin/basePath', 'appUserSessionVO': {'encPwd': None, 'usrClsCd': None, 'usrDeviceId': None, 'usrSeq': None, 'voucherEndDttm': None, 'voucherSeq': None, 'usrType': None, 'loginId': None, 'usrMpnNo': None, 'snsType': None, 'mbId': None, 'mpnLostYn': None, 'lang': 'LAG_001', 'orgType': None, 'snsId': None, 'viewFlg': 'list', 'usrBirthDate': None, 'sexCd': None, 'rentEncPwd': None, 'telecomClsCd': None, 'authCiVal': None, 'authClsCd': None, 'mbTelNo': None, 'mbEmailName': None, 'mbPostNo': None, 'mbAddr1': None, 'mbAddr2': None, 'parentSexCd': None, 'parentBirthDate': None, 'parentMpnNo': None, 'emailSendAgreeYn': None, 'lastLoginDttm': None, 'mbWgt': None, 'langClsCd': None, 'leaveYn': None, 'leaveReasonCd': None, 'leaveDttm': None, 'mbInfoColecAgreeDttm': None, 'mpnLostDttm': None, 'pagingYn': None, 'usrIp': None, 'partyVoucherSeq': None, 'elecVoucherSeq': None, 'requestSeq': None, 'usrDeviceType': None, 'authDiVal': None, 'snsEmail': None, 'tCardYn': None, 'mCardYn': None, 'mainType': None, 'regDttm': None, 'appOsType': None, 'totalRecordCount': 0, 'firstRecordIndex': 0, 'recordCountPerPage': 0, 'pageSize': 0, 'currentPageNo': 1, 'searchValue': None, 'searchParameter': None, 'searchDate': None, 'searchStartDate': None, 'searchEndDate': None, 'mode': None}, 'loginYn': 'N', 'realtimeList': [{'stationId': 'ST-4', 'stationImgFileName': '', 'stationName': '102. 망원역 1번출구 앞', 'stationLongitude': '126.91062927', 'stationLatitude': '37.55564880', 'rackTotCnt': '15', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '25', 'parkingELECBikeCnt': '4', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-5', 'stationImgFileName': '', 'stationName': '103. 망원역 2번출구 앞', 'stationLongitude': '126.91083527', 'stationLatitude': '37.55495071', 'rackTotCnt': '14', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '13', 'parkingELECBikeCnt': '2', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-6', 'stationImgFileName': '', 'stationName': '104. 합정역 1번출구 앞', 'stationLongitude': '126.91498566', 'stationLatitude': '37.55062866', 'rackTotCnt': '13', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '1', 'parkingELECBikeCnt': '0', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-7', 'stationImgFileName': '', 'stationName': '105. 합정역 5번출구 앞', 'stationLongitude': '126.91482544', 'stationLatitude': '37.55000687', 'rackTotCnt': '5', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '2', 'parkingELECBikeCnt': '0', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-8', 'stationImgFileName': '', 'stationName': '106. 합정역 7번출구 앞', 'stationLongitude': '126.91282654', 'stationLatitude': '37.54864502', 'rackTotCnt': '12', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '0', 'parkingELECBikeCnt': '0', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-9', 'stationImgFileName': '', 'stationName': '107. 신한은행 서교동지점', 'stationLongitude': '126.91850281', 'stationLatitude': '37.55751038', 'rackTotCnt': '5', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '7', 'parkingELECBikeCnt': '0', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-10', 'stationImgFileName': '', 'stationName': '108. 서교동 사거리', 'stationLongitude': '126.91861725', 'stationLatitude': '37.55274582', 'rackTotCnt': '10', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '0', 'parkingELECBikeCnt': '0', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-11', 'stationImgFileName': '', 'stationName': '109. 제일빌딩 앞', 'stationLongitude': '126.91998291', 'stationLatitude': '37.54769135', 'rackTotCnt': '10', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '4', 'parkingELECBikeCnt': '0', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-15', 'stationImgFileName': '', 'stationName': '111. 상수역 2번출구 앞', 'stationLongitude': '126.92353058', 'stationLatitude': '37.54787064', 'rackTotCnt': '10', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '2', 'parkingELECBikeCnt': '0', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-16', ' ...

# %%
bike_df = pd.json_normalize(bike , 'realtimeList')
print(type(bike_df)) # <class 'pandas.core.frame.DataFrame'>
print(len(bike_df))
print(bike_df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 2717
# Index(['stationId', 'stationImgFileName', 'stationName', 'stationLongitude',
#        'stationLatitude', 'rackTotCnt', 'parkingBikeTotCnt',
#        'parkingQRBikeCnt', 'parkingELECBikeCnt', 'stationSeCd', 'mode'],
#       dtype='object')

# %%
bike_df.columns
# Out:
# Index(['stationId', 'stationImgFileName', 'stationName', 'stationLongitude',
#        'stationLatitude', 'rackTotCnt', 'parkingBikeTotCnt',
#        'parkingQRBikeCnt', 'parkingELECBikeCnt', 'stationSeCd', 'mode'],
#       dtype='object')

# %%
bike_df_map = bike_df[
    [
    'mode',
    'parkingBikeTotCnt',
    'parkingELECBikeCnt',
    'parkingQRBikeCnt',
    'rackTotCnt',
    'stationId',
    'stationImgFileName',
    'stationLatitude',
    'stationLongitude',
    'stationName',
    'stationSeCd'
    ]
]
bike_df_map
# Out:
#       mode parkingBikeTotCnt parkingELECBikeCnt parkingQRBikeCnt rackTotCnt  \
# 0     None                 0                  4               25         15
# 1     None                 0                  2               13         14
# 2     None                 0                  0                1         13
# 3     None                 0                  0                2          5
# 4     None                 0                  0                0         12
# ...    ...               ...                ...              ...        ...
# 2712  None                 0                  1                1         10
# 2713  None                 0                  3                2         13
# 2714  None                 0                  0                0          5
# 2715  None                 0                  2               13          5
# 2716  None                 0                  0                0          8
#
#      stationId stationImgFileName stationLatitude stationLongitude  \
# 0         ST-4                        37.55564880     126.91062927
# 1         ST-5                        37.55495071     126.91083527
# 2         ST-6                        37.55062866     126.91498566
# 3         ST-7                        37.55000687     126.91482544
# 4         ST-8                        37.54864502     126.91282654
# ...        ...                ...             ...              ...
# 2712   ST-3239                        37.52834702     126.93008423
# 2713   ST-3250                        37.50611877     126.90161133
# 2714   ST-3161                        37.56092453     126.99066162
# 2715   ST-3210                        37.56104279     127.01821136
# 2716   ST-3255                        37.56062698     126.96768188
#
#                  stationName stationSeCd
# 0            102. 망원역 1번출구 앞     RAK_002
# 1            103. 망원역 2번출구 앞     RAK_002
# 2            104. 합정역 1번출구 앞     RAK_002
# 3            105. 합정역 5번출구 앞     RAK_002
# 4            106. 합정역 7번출구 앞     RAK_002
# ...                      ...         ...
# 2712          5870. LG트윈타워 앞     RAK_002
# 2713            5871. 건영상가 앞     RAK_002
# 2714           6053. 중부세무서 앞     RAK_002
# 2715  6054.청구e편한세상아파트 113동 앞     RAK_002
# 2716              6055. 한국경제     RAK_002
#
# [2717 rows x 11 columns]

# %%
# dtype 속성으로 데이터 프레임을 구성하는 컬럼들의 자료형을 확인할 수 있다.
bike_df_map.dtypes
# Out:
# mode                  object
# parkingBikeTotCnt     object
# parkingELECBikeCnt    object
# parkingQRBikeCnt      object
# rackTotCnt            object
# stationId             object
# stationImgFileName    object
# stationLatitude       object
# stationLongitude      object
# stationName           object
# stationSeCd           object
# dtype: object

# %%
# info() 메소드를 사용해도 데이터프레임을 구성하는 컬럼들의 자료형을 확인할 수 있다.
bike_df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2717 entries, 0 to 2716
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mode                0 non-null      object
#  1   parkingBikeTotCnt   2717 non-null   object
#  2   parkingELECBikeCnt  2717 non-null   object
#  3   parkingQRBikeCnt    2717 non-null   object
#  4   rackTotCnt          2717 non-null   object
#  5   stationId           2717 non-null   object
#  6   stationImgFileName  2717 non-null   object
#  7   stationLatitude     2717 non-null   object
#  8   stationLongitude    2717 non-null   object
#  9   stationName         2717 non-null   object
#  10  stationSeCd         2717 non-null   object
# dtypes: object(11)
# memory usage: 233.6+ KB

# %%
bike_df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2717 entries, 0 to 2716
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mode                0 non-null      object
#  1   parkingBikeTotCnt   2717 non-null   object
#  2   parkingELECBikeCnt  2717 non-null   object
#  3   parkingQRBikeCnt    2717 non-null   object
#  4   rackTotCnt          2717 non-null   object
#  5   stationId           2717 non-null   object
#  6   stationImgFileName  2717 non-null   object
#  7   stationLatitude     2717 non-null   object
#  8   stationLongitude    2717 non-null   object
#  9   stationName         2717 non-null   object
#  10  stationSeCd         2717 non-null   object
# dtypes: object(11)
# memory usage: 233.6+ KB

# %%
bike_df_map['stationLatitude'] = bike_df_map['stationLatitude'].astype(float)
bike_df_map['stationLongitude'] = bike_df_map['stationLongitude'].astype(float)
bike_df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2717 entries, 0 to 2716
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mode                0 non-null      object
#  1   parkingBikeTotCnt   2717 non-null   object
#  2   parkingELECBikeCnt  2717 non-null   object
#  3   parkingQRBikeCnt    2717 non-null   object
#  4   rackTotCnt          2717 non-null   object
#  5   stationId           2717 non-null   object
#  6   stationImgFileName  2717 non-null   object
#  7   stationLatitude     2717 non-null   float64
#  8   stationLongitude    2717 non-null   float64
#  9   stationName         2717 non-null   object
#  10  stationSeCd         2717 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 233.6+ KB

# %%
bike_df_map[bike_df_map['stationId'] == 'ST-3255']
# Out:
#       mode parkingBikeTotCnt parkingELECBikeCnt parkingQRBikeCnt rackTotCnt  \
# 2716  None                 0                  0                0          8
#
#      stationId stationImgFileName  stationLatitude  stationLongitude  \
# 2716   ST-3255                           37.560627        126.967682
#
#      stationName stationSeCd
# 2716  6055. 한국경제     RAK_002

# %%
bike_df_map
bikeMap = folium.Map(location=[37.51156 , 126.849449], zoom_start=10)
for index, data in bike_df_map.iterrows():
    popup = folium.Popup('{}. {}'.format(index+1 , data['stationName']) , max_width=300)
    folium.Marker(location=[data['stationLatitude'],data['stationLongitude']] , popup=popup).add_to(bikeMap)
bikeMap.save('./seoulBike.html')
bikeMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc99c10121fea4ae2249dc1508fe0ef4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc99c10121fea4ae2249dc1508fe0ef4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc99c10121fea4ae2249dc1508fe0ef4 = L.map(
#                 &quot;map_cc99c10121fea4ae2249dc1508fe0ef4&quot;,
#                 {
#                     center: [37.51156, 126.849449],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_156566a822f867ff578cedd1c2489ac5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cc99c10121fea4ae2249dc1508fe0ef4);
#
#
#             var marker_4744d0c185ca48a047fc551ad14c6805 = L.marker(
#                 [37.5556488, 126.91062927],
#                 {}
#             ).addTo(map_cc99c10121fea4ae2249dc1508fe0ef4);
#
#
#         var popup_a1033cdcf5c57e5edf7032ce357df95b = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_5650254e54f0d808332fc528e3e49ea5 = $(`&lt;div id=&quot;html_5650254e54f0d808332fc528e3e49ea5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1. 102. 망원역 1번출구 앞&lt;/div&gt;`)[0];
#                 popup_a1033cdcf5c57e5edf7032ce357df95b.setContent(html_5650254e54f0d808332fc528e3e49ea5);
#
#
#
#         marker_4744d0c185ca48a047fc551ad14c6805.bindPopup(popup_a1033cdcf5c57e5edf7032ce357df95b)
#         ;
#
#
#
#
#             var marker_0090cc073ff0b51fb38b9b72c421b798 = L.marker(
#                 [37.55495071, 126.91083527],
#                 {}
#             ).addTo(map_cc99c10121fea4ae2249dc1508fe0ef4);
#
#
#         var popup_151916436fe5530d27d1d521c0762dbe = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e058cb58d0e08e7f282fb63290175518 = $(`&lt;div id=&quot;html_e058cb58d0e08e7f282fb63290175518&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2. 103. 망원역 2번출구 앞&lt;/div&gt;`)[0];
#                 popup_151916436fe5530d27d1d521c0762dbe.setContent(html_e058cb58d0e08e7f282fb63290175518);
#
#
#
#         marker_0090cc073ff0b51fb38b9b72c421b798.bindPopup(popup_151916436fe5530d27d1d521c0762dbe)
#         ;
#
#
#
#
#             var marker_0435c720b3114c0e25848f1d179c372d = L.marker(
#                 [37.55062866, 126.91498566],
#                 {}
#             ).addTo(map_cc99c10121fea4ae2249dc1508fe0ef4);
#
#
#         var popup_0d7527f40a340cc8869179221be82ac6 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_32f163b1ae4bbadfb9a12e144908a3a7 = $(`&lt;div id=&quot;html_32f163b1ae4bbadfb9a12e144908a3a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3. 104. 합정역 1번출구 앞&lt;/div&gt;`)[0];
#                 popup_0d7527f40a340cc8869179221be82ac6.setContent(html_32f163b1ae4bbadfb9a12e144908a3a7);
#
#
#
#         marker_0435c720b3114c0e25848f1d179c372d.bindPopup(popup_0d7527f40a340cc8869179221be82ac6)
#         ;
#
#
#
#
#             var marker_d54eb2a04bf77743df85c4285ca16a8f = L.marker(
#                 [37.55000687, 126.91482544],
#                 {}
#             ).addTo(map_cc99c10121fea4ae2249dc1508fe0ef4);
#
#
#         var popup_d08c5e297764a382dbccf1fa8ef7f57f = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_6f5277bca211e8e2ca2d3e563ff48249 = $(`&lt;div id=&quot;html_6f5277bca211e8e2ca2d3e563ff48249&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4. 105. 합정역 5번출구 앞&lt;/div&gt;`)[0];
#                 popup_d08c5e297764a382dbccf1fa8ef7f57f.setContent(html_6f5277bca211e8e2ca2d3e563ff48249);
#
#
#
#         marker_d54eb2a04bf77743df85c4285ca16a8f.bindPopup(popup_d08c5e297764a382dbccf1fa8ef7f57f)
#         ;
#
#
#
#
#             var marker_397510a19a899f7ad85668760d1ecbec = L.marker(
#                 [37.54864502, 126.91282654],
#                 {}
#             ).addTo(map_cc99c10121fea4ae2249dc1508fe0ef4);
#
#
#         var popup_b027653580ccff9aeead4d5088c6f081 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_26d70a634a74337a6233e7f4b2ba9fbd = $(`&lt;div id=&quot;html_26d70a634a74337a6233e7f4b2ba9fbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5. 106. 합정역 7번출구 앞&lt;/div&gt;`)[0];
#                 popup_b027653580ccff9aeead4d5088c6f081.setContent(html_26d70a634a74337a6233e7f4b2ba9fbd);
#
#
#
#         marker_397510a19a899f7ad85668760d1ecbec.bindPopup(popup_b027653580ccff9aeead4d5088c6f081)
#         ;
#
#
#
#
#             var marker_8b35c0b42a0100797f46eeec45d9d761 = L.marker(
#                 [37.55751038, 126.91850281],
#                 {}
