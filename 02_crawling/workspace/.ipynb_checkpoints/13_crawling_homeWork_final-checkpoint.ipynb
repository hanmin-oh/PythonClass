# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Computer.use_jedi = False
import requests
import folium
# !pip install pandas # 파이썬 데이터 처리
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='D2Coding')

# %%
# 서울 지하철 승하차량
targetSite = 'https://data.gg.go.kr/portal/data/sheet/searchSheetData.do?page=1'
request1 = requests.post(targetSite, data={
    'rows': '1',
    'infId': '7GZ08I0JWSNPY5NVMLLG24313533',
    'infSeq': 1,
    'STATN_NM': '강남',
    'TKALGHT_DIV_NM' : '승차',
    'STD_DE' : '', 
    'STATN_NO' : '',
    'TM05_PSNCNT' : '',
    'TM06_PSNCNT': '',
    'TM07_PSNCNT': '',
    'TM08_PSNCNT': '',
    'TM09_PSNCNT': '',
    'TM10_PSNCNT': '',
    'TM11_PSNCNT': '',
    'TM12_PSNCNT': '',
    'TM13_PSNCNT': '',
    'TM14_PSNCNT': '',
    'TM15_PSNCNT': '',
    'TM16_PSNCNT': '',
    'TM17_PSNCNT': '',
    'TM18_PSNCNT': '',
    'TM19_PSNCNT': '',
    'TM20_PSNCNT': '',
    'TM21_PSNCNT': '',
    'TM22_PSNCNT': '',
    'TM23_PSNCNT': '',
    'TM24_PSNCNT': ''
})
request2 = requests.post(targetSite, data={
    'rows': '1',
    'infId': '7GZ08I0JWSNPY5NVMLLG24313533',
    'infSeq': 1,
    'STATN_NM': '강남',
    'TKALGHT_DIV_NM' : '하차',
    'STD_DE' : '', 
    'STATN_NO' : '',
    'TM05_PSNCNT' : '',
    'TM06_PSNCNT': '',
    'TM07_PSNCNT': '',
    'TM08_PSNCNT': '',
    'TM09_PSNCNT': '',
    'TM10_PSNCNT': '',
    'TM11_PSNCNT': '',
    'TM12_PSNCNT': '',
    'TM13_PSNCNT': '',
    'TM14_PSNCNT': '',
    'TM15_PSNCNT': '',
    'TM16_PSNCNT': '',
    'TM17_PSNCNT': '',
    'TM18_PSNCNT': '',
    'TM19_PSNCNT': '',
    'TM20_PSNCNT': '',
    'TM21_PSNCNT': '',
    'TM22_PSNCNT': '',
    'TM23_PSNCNT': '',
    'TM24_PSNCNT': ''
})
subway1 = request1.json()
print(type(subway1))
print(subway1)
subway2 = request2.json()
print(type(subway2))
print(subway2)
# Out:
# <class 'dict'>
# {'data': [{'STD_DE': '2022-12-31', 'STATN_NO': 2, 'STATN_NM': '강남', 'TKALGHT_DIV_NM': '승차', 'TM05_PSNCNT': 513, 'TM06_PSNCNT': 633, 'TM07_PSNCNT': 461, 'TM08_PSNCNT': 664, 'TM09_PSNCNT': 968, 'TM10_PSNCNT': 1410, 'TM11_PSNCNT': 2153, 'TM12_PSNCNT': 2658, 'TM13_PSNCNT': 2923, 'TM14_PSNCNT': 3447, 'TM15_PSNCNT': 4282, 'TM16_PSNCNT': 4714, 'TM17_PSNCNT': 4388, 'TM18_PSNCNT': 3518, 'TM19_PSNCNT': 2630, 'TM20_PSNCNT': 2598, 'TM21_PSNCNT': 3215, 'TM22_PSNCNT': 3277, 'TM23_PSNCNT': 1656, 'TM24_PSNCNT': 380}], 'total': 756, 'count': 756, 'page': 1, 'rows': 1, 'pages': 756}
# <class 'dict'>
# {'data': [{'STD_DE': '2022-12-31', 'STATN_NO': 2, 'STATN_NM': '강남', 'TKALGHT_DIV_NM': '하차', 'TM05_PSNCNT': 199, 'TM06_PSNCNT': 800, 'TM07_PSNCNT': 804, 'TM08_PSNCNT': 2323, 'TM09_PSNCNT': 4370, 'TM10_PSNCNT': 3343, 'TM11_PSNCNT': 3087, 'TM12_PSNCNT': 3408, 'TM13_PSNCNT': 3819, 'TM14_PSNCNT': 3174, 'TM15_PSNCNT': 3168, 'TM16_PSNCNT': 3188, 'TM17_PSNCNT': 3262, 'TM18_PSNCNT': 2977, 'TM19_PSNCNT': 2449, 'TM20_PSNCNT': 2026, 'TM21_PSNCNT': 2185, 'TM22_PSNCNT': 1820, 'TM23_PSNCNT': 1069, 'TM24_PSNCNT': 530}], 'total': 756, 'count': 756, 'page': 1, 'rows': 1, 'pages': 756}

# %%
# 데이터프레임 생성
subway_df1 = pd.json_normalize(subway1['data']) # 승차
print(subway_df1)  # 데이터프레임 내용 출력
print(subway_df1.info())  
subway_df1

subway_df2 = pd.json_normalize(subway2['data']) # 하차
print(subway_df2)  # 데이터프레임 내용 출력
print(subway_df2.info())  
subway_df2
# Out:
#        STD_DE  STATN_NO STATN_NM TKALGHT_DIV_NM  TM05_PSNCNT  TM06_PSNCNT  \
# 0  2022-12-31         2       강남             승차          513          633
#
#    TM07_PSNCNT  TM08_PSNCNT  TM09_PSNCNT  TM10_PSNCNT  ...  TM15_PSNCNT  \
# 0          461          664          968         1410  ...         4282
#
#    TM16_PSNCNT  TM17_PSNCNT  TM18_PSNCNT  TM19_PSNCNT  TM20_PSNCNT  \
# 0         4714         4388         3518         2630         2598
#
#    TM21_PSNCNT  TM22_PSNCNT  TM23_PSNCNT  TM24_PSNCNT
# 0         3215         3277         1656          380
#
# [1 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   STD_DE          1 non-null      object
#  1   STATN_NO        1 non-null      int64
#  2   STATN_NM        1 non-null      object
#  3   TKALGHT_DIV_NM  1 non-null      object
#  4   TM05_PSNCNT     1 non-null      int64
#  5   TM06_PSNCNT     1 non-null      int64
#  6   TM07_PSNCNT     1 non-null      int64
#  7   TM08_PSNCNT     1 non-null      int64
#  8   TM09_PSNCNT     1 non-null      int64
#  9   TM10_PSNCNT     1 non-null      int64
#  10  TM11_PSNCNT     1 non-null      int64
#  11  TM12_PSNCNT     1 non-null      int64
#  12  TM13_PSNCNT     1 non-null      int64
#  13  TM14_PSNCNT     1 non-null      int64
#  14  TM15_PSNCNT     1 non-null      int64
#  15  TM16_PSNCNT     1 non-null      int64
#  16  TM17_PSNCNT     1 non-null      int64
#  17  TM18_PSNCNT     1 non-null      int64
#  18  TM19_PSNCNT     1 non-null      int64
#  19  TM20_PSNCNT     1 non-null      int64
#  20  TM21_PSNCNT     1 non-null      int64
#  21  TM22_PSNCNT     1 non-null      int64
#  22  TM23_PSNCNT     1 non-null      int64
#  23  TM24_PSNCNT     1 non-null      int64
# dtypes: int64(21), object(3)
# memory usage: 320.0+ bytes
# None
#        STD_DE  STATN_NO STATN_NM TKALGHT_DIV_NM  TM05_PSNCNT  TM06_PSNCNT  \
# 0  2022-12-31         2       강남             하차          199          800
#
#    TM07_PSNCNT  TM08_PSNCNT  TM09_PSNCNT  TM10_PSNCNT  ...  TM15_PSNCNT  \
# 0          804         2323         4370         3343  ...         3168
#
#    TM16_PSNCNT  TM17_PSNCNT  TM18_PSNCNT  TM19_PSNCNT  TM20_PSNCNT  \
# 0         3188         3262         2977         2449         2026
#
#    TM21_PSNCNT  TM22_PSNCNT  TM23_PSNCNT  TM24_PSNCNT
# 0         2185         1820         1069          530
#
# [1 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   STD_DE          1 non-null      object
#  1   STATN_NO        1 non-null      int64
#  2   STATN_NM        1 non-null      object
#  3   TKALGHT_DIV_NM  1 non-null      object
#  4   TM05_PSNCNT     1 non-null      int64
#  5   TM06_PSNCNT     1 non-null      int64
#  6   TM07_PSNCNT     1 non-null      int64
#  7   TM08_PSNCNT     1 non-null      int64
#  8   TM09_PSNCNT     1 non-null      int64
#  9   TM10_PSNCNT     1 non-null      int64
#  10  TM11_PSNCNT     1 non-null      int64
#  11  TM12_PSNCNT     1 non-null      int64
#  12  TM13_PSNCNT     1 non-null      int64
#  13  TM14_PSNCNT     1 non-null      int64
#  14  TM15_PSNCNT     1 non-null      int64
#  15  TM16_PSNCNT     1 non-null      int64
#  16  TM17_PSNCNT     1 non-null      int64
#  17  TM18_PSNCNT     1 non-null      int64
#  18  TM19_PSNCNT     1 non-null      int64
#  19  TM20_PSNCNT     1 non-null      int64
#  20  TM21_PSNCNT     1 non-null      int64
#  21  TM22_PSNCNT     1 non-null      int64
#  22  TM23_PSNCNT     1 non-null      int64
#  23  TM24_PSNCNT     1 non-null      int64
# dtypes: int64(21), object(3)
# memory usage: 320.0+ bytes
# None
#        STD_DE  STATN_NO STATN_NM TKALGHT_DIV_NM  TM05_PSNCNT  TM06_PSNCNT  \
# 0  2022-12-31         2       강남             하차          199          800
#
#    TM07_PSNCNT  TM08_PSNCNT  TM09_PSNCNT  TM10_PSNCNT  ...  TM15_PSNCNT  \
# 0          804         2323         4370         3343  ...         3168
#
#    TM16_PSNCNT  TM17_PSNCNT  TM18_PSNCNT  TM19_PSNCNT  TM20_PSNCNT  \
# 0         3188         3262         2977         2449         2026
#
#    TM21_PSNCNT  TM22_PSNCNT  TM23_PSNCNT  TM24_PSNCNT
# 0         2185         1820         1069          530
#
# [1 rows x 24 columns]

# %%
subway_df2.columns
# Out:
# Index(['STD_DE', 'STATN_NO', 'STATN_NM', 'TKALGHT_DIV_NM', 'TM05_PSNCNT',
#        'TM06_PSNCNT', 'TM07_PSNCNT', 'TM08_PSNCNT', 'TM09_PSNCNT',
#        'TM10_PSNCNT', 'TM11_PSNCNT', 'TM12_PSNCNT', 'TM13_PSNCNT',
#        'TM14_PSNCNT', 'TM15_PSNCNT', 'TM16_PSNCNT', 'TM17_PSNCNT',
#        'TM18_PSNCNT', 'TM19_PSNCNT', 'TM20_PSNCNT', 'TM21_PSNCNT',
#        'TM22_PSNCNT', 'TM23_PSNCNT', 'TM24_PSNCNT'],
#       dtype='object')

# %%
# 열 이름 변경
subway_df1.columns = ['STD_DE', 'STATN_NO', 'STATN_NM', 'DIV', '05시', '06시', '07시', '08시', '09시', '10시', '11시', '12시', '13시', '14시', '15시', '16시', '17시', '18시', '19시', '20시', '21시', '22시', '23시', '24시']
subway_df2.columns = ['STD_DE', 'STATN_NO', 'STATN_NM', 'DIV', '05시', '06시', '07시', '08시', '09시', '10시', '11시', '12시', '13시', '14시', '15시', '16시', '17시', '18시', '19시', '20시', '21시', '22시', '23시', '24시']

# 역 이름 추출
desired_station_name = subway_df1.loc[0, 'STATN_NM']

# 승차 데이터 추출
entry_data = subway_df1.iloc[0, 4:24]

# 하차 데이터 추출
exit_data = subway_df2.iloc[0, 4:24]

# 시간대별 데이터 시각화
plt.figure(figsize=(10, 6))
plt.plot(entry_data.index, entry_data, marker='o', label='승차', color='b')
plt.plot(exit_data.index, exit_data, marker='o', label='하차', color='r')

# x축 인덱스 변경
time_labels = [f'{i:02d}시' for i in range(5, 25)]
plt.xticks(range(len(entry_data)), time_labels, fontsize=12, rotation=45)

plt.title(f'{desired_station_name}역 2022년 12월 31일 지하철 시간대별 승하차 승객 수')
plt.xlabel('시간대')
plt.ylabel('승객 수')
plt.legend(title='승객수', loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()
